# %% [markdown]
# # Retrieve your DKRZ data form
#
#
# Via this form you can retrieve previously generated data forms and make them accessible via the Web again for completion.
#
# Additionally you can get information on the data ingest process status related to your form based request.

# %%
from dkrz_forms import form_widgets
form_widgets.show_status('form-retrieval')
# Out:
# Info: myconfig not found - taking default config

# %% [markdown]
# ### Please provide your last name
#
# please set your last name in the cell below
#
#   ---- e.g. MY_LAST_NAME = "mueller"
#
# and evaluate the cell (Press "Shift"-Return in the cell)
#
# you will then be asked for the key associated to your form
#
# (the key was provided to you as part of your previous form generation step)

# %%
from dkrz_forms import form_handler, form_widgets

#please provide your last name - replacing ... below
MY_LAST_NAME = "ki" 


form_info = form_widgets.check_and_retrieve(MY_LAST_NAME)
# Out:
# Enter your form key: ········
# ---- Your Name:  ki ki
# ---- Your email:  ki
# ---- Name of this submission form:  ESGF_replication_ki_123
# {'first_name': u'ki', 'last_name': u'ki', 'form_repo': '/home/stephan/tmp/Repos/form_repo/ESGF_replication', 'form_path': u'/home/stephan/tmp/Repos/form_repo/ESGF_replication/ESGF_replication_ki_123.ipynb', 'project': 'ESGF_replication', 'pwd': 'FHQ3EI', 'key': u'123', 'form_name': u'ESGF_replication_ki_123', 'form_json': u'/home/stephan/tmp/Repos/form_repo/ESGF_replication/ESGF_replication_ki_123.json', 'email': u'ki'}
# ('--- copy from:', u'/home/stephan/tmp/Repos/form_repo/ESGF_replication/ESGF_replication_ki_123.ipynb')
# ('--- to: ', '/home/stephan/Repos/ENES-EUDAT/submission_forms/test/forms/ESGF_replication')
# --------------------------------------------------------------------
#    Your submission form was retrieved and is accessible via the following link:
# http://localhost:8888/notebooks/Repos/ENES-EUDAT/submission_forms/test/forms/ESGF_replication/ESGF_replication_ki_123.ipynb
# --------------------------------------------------------------------

# %% [markdown]
# ## Get status information related to your form based request

# %%
# To be completed

# %% [markdown]
# ## Contact the DKRZ data managers for form related issues

# %%
# tob be completed
